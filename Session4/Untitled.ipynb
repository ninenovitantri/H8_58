# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (1.20.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys

# %%
import numpy as np

# %%
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in c:\programdata\anaconda3\lib\site-packages (8.2.0)

# %%
from PIL import Image

infile = "image.png"

im = Image.open(infile) 
display(im)

print(infile, im.format, "%dx%d" %  im.size, im.mode)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x1080 at 0x143706464F0>
# image.png PNG 1920x1080 RGBA

# %%
out
out ==im.resize((128,im.rotate(45) #128))
degrees counter-clockwise
out
=
im.transpose(Image.FLIP_LEFT_RIGHT)
out
=
im.transpose(Image.FLIP_TOP_BOTTOM)
# Out:
#   File "<ipython-input-10-64ab4e830fb7>", line 3
#     =
#     ^
# SyntaxError: invalid syntax

# %%
out =vim.resize((128,128))
out = im.rotate(45) #degrees counter-clockwise
out = im.transpose(Image.FLIP_LEFT_RIGHT)
out = im.transpose(Image.FLIP_TOP_BOTTOM)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-0c08072f89bf> in <module>
# ----> 1 out =vim.resize((128,128))
#       2 out = im.rotate(45) #degrees counter-clockwise
#       3 out = im.transpose(Image.FLIP_LEFT_RIGHT)
#       4 out = im.transpose(Image.FLIP_TOP_BOTTOM)
#
# NameError: name 'vim' is not defined

# %%
out = im.resize((128,128))
display(out)
out = im.rotate(45) #degrees counter-clockwise
display(out)
out = im.transpose(Image.FLIP_LEFT_RIGHT)
display(out)
out = im.transpose(Image.FLIP_TOP_BOTTOM)
display(out)
# Out:
# <PIL.Image.Image image mode=RGBA size=128x128 at 0x143701D3D00>
# <PIL.Image.Image image mode=RGBA size=1920x1080 at 0x1437080FE20>
# <PIL.Image.Image image mode=RGBA size=1920x1080 at 0x143701E53D0>
# <PIL.Image.Image image mode=RGBA size=1920x1080 at 0x143701D3700>

# %%
from PIL import Image, ImageFilter

out1 = im.filter(ImageFilter.BLUR)
display(out1)
out2 = im.filter(ImageFilter.GaussianBlur(radius=20))
display(out2)
# Out:
# <PIL.Image.Image image mode=RGBA size=1920x1080 at 0x1437080FAF0>
# <PIL.Image.Image image mode=RGBA size=1920x1080 at 0x143701E53D0>
