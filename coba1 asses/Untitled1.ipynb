# %%
# import pandas and numpy
import numpy as np 
import pandas as pd

# %%
# import file
df_lon= pd.read_csv('C:/Users/Nine/Documents/hacktiv8/Assesment 1/2021-06-city-of-london-street.csv')

# %%
df_lon.head()
# Out:
#                                             Crime ID    Month  \
# 0                                                NaN  2021-06
# 1  f0f8c98f14e0505abb6bc9e542e0f1f37f2cd6ef5b099b...  2021-06
# 2                                                NaN  2021-06
# 3  9c93ff5c8cee3bde9224525f35b9f3c27e68acdec1e41b...  2021-06
# 4  f11c173771861690ba65a79fe7b492a5d4c547e98becf6...  2021-06
#
#              Reported by           Falls within  Longitude   Latitude  \
# 0  City of London Police  City of London Police  -0.106453  51.518207
# 1  City of London Police  City of London Police  -0.111962  51.518494
# 2  City of London Police  City of London Police  -0.095914  51.520348
# 3  City of London Police  City of London Police  -0.095892  51.516391
# 4  City of London Police  City of London Police  -0.095892  51.516391
#
#                          Location  LSOA code            LSOA name  \
# 0  On or near Charterhouse Street  E01000916          Camden 027B
# ...

# %%
df_lon.tail()
# Out:
#                                               Crime ID    Month  \
# 565  3a6a36101e7c6b7a431c13756c017d23f6d020e586065e...  2021-06
# 566  21b27b130baafeae0a31ff73ed568c863f02bceed585cb...  2021-06
# 567  9da3d839603892a84e8ef0861ff36787b99bee1ca7c7e6...  2021-06
# 568  ae6e17dab724c47d8f6cc52f95179b645794b1544735a2...  2021-06
# 569  971a230ab1bc5ded6b5978d2675d31451119e595d290bc...  2021-06
#
#                Reported by           Falls within  Longitude  Latitude  \
# 565  City of London Police  City of London Police        NaN       NaN
# 566  City of London Police  City of London Police        NaN       NaN
# 567  City of London Police  City of London Police        NaN       NaN
# 568  City of London Police  City of London Police        NaN       NaN
# 569  City of London Police  City of London Police        NaN       NaN
#
#         Location LSOA code LSOA name   Crime type Last outcome category  \
# 565  No Location       NaN       NaN  Other crime   Under investigation
# ...

# %%
df_lon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 570 entries, 0 to 569
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Crime ID               471 non-null    object
#  1   Month                  570 non-null    object
#  2   Reported by            570 non-null    object
#  3   Falls within           570 non-null    object
#  4   Longitude              520 non-null    float64
#  5   Latitude               520 non-null    float64
#  6   Location               570 non-null    object
#  7   LSOA code              520 non-null    object
#  8   LSOA name              520 non-null    object
#  9   Crime type             570 non-null    object
#  10  Last outcome category  471 non-null    object
#  11  Context                0 non-null      float64
# dtypes: float64(3), object(9)
# memory usage: 53.6+ KB

# %%
df_lon.describe()
# Out:
#         Longitude    Latitude  Context
# count  520.000000  520.000000      0.0
# mean    -0.087006   51.514977      NaN
# std      0.009890    0.003652      NaN
# min     -0.112519   51.504245      NaN
# 25%     -0.094115   51.512462      NaN
# 50%     -0.084967   51.514872      NaN
# 75%     -0.079786   51.517568      NaN
# max     -0.036310   51.533331      NaN

# %%
df_lon.columns.values
# Out:
# array(['Crime ID', 'Month', 'Reported by', 'Falls within', 'Longitude',
#        'Latitude', 'Location', 'LSOA code', 'LSOA name', 'Crime type',
#        'Last outcome category', 'Context'], dtype=object)

# %%
print(df_lon.shape)
# Out:
# (570, 12)

# %%
print(df_lon.isnull().any())
# Out:
# Crime ID                  True
# Month                    False
# Reported by              False
# Falls within             False
# Longitude                 True
# Latitude                  True
# Location                 False
# LSOA code                 True
# LSOA name                 True
# Crime type               False
# Last outcome category     True
# Context                   True
# dtype: bool

# %%
df_lon.isnull().sum()
# Out:
# Crime ID                  99
# Month                      0
# Reported by                0
# Falls within               0
# Longitude                 50
# Latitude                  50
# Location                   0
# LSOA code                 50
# LSOA name                 50
# Crime type                 0
# Last outcome category     99
# Context                  570
# dtype: int64

# %%
# clean up the dataset to remove unnecessary columns (eg. REG) 
df_lon.drop(['Context'], axis=1, inplace=True)

# %%
df_lon.head()
# Out:
#                                             Crime ID    Month  \
# 0                                                NaN  2021-06
# 1  f0f8c98f14e0505abb6bc9e542e0f1f37f2cd6ef5b099b...  2021-06
# 2                                                NaN  2021-06
# 3  9c93ff5c8cee3bde9224525f35b9f3c27e68acdec1e41b...  2021-06
# 4  f11c173771861690ba65a79fe7b492a5d4c547e98becf6...  2021-06
#
#              Reported by           Falls within  Longitude   Latitude  \
# 0  City of London Police  City of London Police  -0.106453  51.518207
# 1  City of London Police  City of London Police  -0.111962  51.518494
# 2  City of London Police  City of London Police  -0.095914  51.520348
# 3  City of London Police  City of London Police  -0.095892  51.516391
# 4  City of London Police  City of London Police  -0.095892  51.516391
#
#                          Location  LSOA code            LSOA name  \
# 0  On or near Charterhouse Street  E01000916          Camden 027B
# ...

# %%
#menghilangkan semua baris dan kolom yang ada NaN nya
df_lon= df_lon.dropna()

# %%
df_lon.head()
# Out:
#                                             Crime ID    Month  \
# 1  f0f8c98f14e0505abb6bc9e542e0f1f37f2cd6ef5b099b...  2021-06
# 3  9c93ff5c8cee3bde9224525f35b9f3c27e68acdec1e41b...  2021-06
# 4  f11c173771861690ba65a79fe7b492a5d4c547e98becf6...  2021-06
# 5  e457be6a5512f6c9413c7772878f1abd48dca11e53a5eb...  2021-06
# 6  f148fd49ac9719a91a12cc0dd38bb9efc3a193d422c8f9...  2021-06
#
#              Reported by           Falls within  Longitude   Latitude  \
# 1  City of London Police  City of London Police  -0.111962  51.518494
# 3  City of London Police  City of London Police  -0.095892  51.516391
# 4  City of London Police  City of London Police  -0.095892  51.516391
# 5  City of London Police  City of London Police  -0.098642  51.517146
# 6  City of London Police  City of London Police  -0.097736  51.520206
#
#                                   Location  LSOA code            LSOA name  \
# 1                     On or near Nightclub  E01000914          Camden 028B
# ...

# %%
df_lon.tail()
# Out:
#                                               Crime ID    Month  \
# 515  7dc364b3de39234825383121a1449df96730f29063d63f...  2021-06
# 516  6385147d64fc84cf01f2b1579d9d0766f8deda38e98b52...  2021-06
# 517  c3ab7937db5d1671f3a03b2576bb3355606d091d3a66ef...  2021-06
# 518  1543fc27fe2fdcbb4d959f2473816984e1495e1b606eb6...  2021-06
# 519  ac56c749b98216ba7e88f20aae3d2d64a2339a7d6518eb...  2021-06
#
#                Reported by           Falls within  Longitude   Latitude  \
# 515  City of London Police  City of London Police  -0.074901  51.506255
# 516  City of London Police  City of London Police  -0.076031  51.509547
# 517  City of London Police  City of London Police  -0.074901  51.506255
# 518  City of London Police  City of London Police  -0.074901  51.506255
# 519  City of London Police  City of London Police  -0.111974  51.513683
#
#                     Location  LSOA code           LSOA name  \
# 515          On or near A100  E01004293  Tower Hamlets 027B
# ...

# %%
#df_lon.drop(['Crime ID','Month','Reported by','Falls within', 'Longitude', 'Latitude', 'Location', 'LSOA code', 'Last outcome category'], axis=1, inplace=True)

# %%
df_lon.head()
# Out:
#                                             Crime ID    Month  \
# 1  f0f8c98f14e0505abb6bc9e542e0f1f37f2cd6ef5b099b...  2021-06
# 3  9c93ff5c8cee3bde9224525f35b9f3c27e68acdec1e41b...  2021-06
# 4  f11c173771861690ba65a79fe7b492a5d4c547e98becf6...  2021-06
# 5  e457be6a5512f6c9413c7772878f1abd48dca11e53a5eb...  2021-06
# 6  f148fd49ac9719a91a12cc0dd38bb9efc3a193d422c8f9...  2021-06
#
#              Reported by           Falls within  Longitude   Latitude  \
# 1  City of London Police  City of London Police  -0.111962  51.518494
# 3  City of London Police  City of London Police  -0.095892  51.516391
# 4  City of London Police  City of London Police  -0.095892  51.516391
# 5  City of London Police  City of London Police  -0.098642  51.517146
# 6  City of London Police  City of London Police  -0.097736  51.520206
#
#                                   Location  LSOA code            LSOA name  \
# 1                     On or near Nightclub  E01000914          Camden 028B
# ...

# %%
df_lon.count()
# Out:
# Crime ID                 437
# Month                    437
# Reported by              437
# Falls within             437
# Longitude                437
# Latitude                 437
# Location                 437
# LSOA code                437
# LSOA name                437
# Crime type               437
# Last outcome category    437
# dtype: int64

# %%
df_lon.rename (columns = {'Crime type' : 'CrimeType'}, inplace=True)

# %%
#df_lon.groupby(['LSOA name',],as_index = False).count().pivot('LSOA name', 'CrimeType')
#df_lon.groupby(['CrimeType','LSOA name'],as_index = False).count().pivot('CrimeType', 'LSOA name')
#df_visual = df_lon.groupby(['LSOA name','CrimeType'],as_index = False).count().pivot('LSOA name','CrimeType')
df_lon.[['LSOA name','CrimeType']].groupby(['LSOA name','CrimeType']).agg(['count'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-7691702b17c3> in <module>
#       2 #df_lon.groupby(['CrimeType','LSOA name'],as_index = False).count().pivot('CrimeType', 'LSOA name')
#       3 #df_visual = df_lon.groupby(['LSOA name','CrimeType'],as_index = False).count().pivot('LSOA name','CrimeType')
# ----> 4 df[['LSOA name','CrimeType']].groupby(['LSOA name','CrimeType']).agg(['count'])
#
# NameError: name 'df' is not defined

# %%
df_lon.head()
# Out:
#              LSOA name                     CrimeType
# 1          Camden 028B  Violence and sexual offences
# 3  City of London 001A                 Bicycle theft
# 4  City of London 001A                   Other theft
# 5  City of London 001A                   Other theft
# 6  City of London 001A                  Public order

# %%
#df_lon.set_index('Crime type', inplace = True)

# %%
df_lon.head()
# Out:
#              LSOA name                     CrimeType
# 1          Camden 028B  Violence and sexual offences
# 3  City of London 001A                 Bicycle theft
# 4  City of London 001A                   Other theft
# 5  City of London 001A                   Other theft
# 6  City of London 001A                  Public order

# %%
df_lon.groupby('LSOA name', dropna=False)[['CrimeType']].count()
# Out:
#                      CrimeType
# LSOA name
# Camden 028B                  1
# City of London 001A         20
# City of London 001B         15
# City of London 001C          3
# City of London 001E         59
# City of London 001F        267
# City of London 001G         34
# Hackney 025D                 1
# Hackney 027G                 1
# Islington 022D               1
# Islington 022H               3
# Islington 023D               4
# Islington 023E               2
# Southwark 003H               1
# Tower Hamlets 015B           4
# Tower Hamlets 019C           1
# Tower Hamlets 021D           2
# Tower Hamlets 021F           1
# Tower Hamlets 027B          16
# Westminster 018B             1

# %%
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df_lon.plot(kind='area', 
             stacked=False,
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('London Crime June 2021')
plt.ylabel('LSOA name')
plt.xlabel('Crime type')

plt.show()

# %%
#df_area = df_lon.groupby(['LSOA name'],as_index = False).count().pivot('LSOA name', 'Crime type')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-d2d273786c12> in <module>
# ----> 1 df_area = df_lon.groupby(['LSOA name'],as_index = False).count().pivot('LSOA name', 'Crime type')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in pivot(self, index, columns, values)
#    6877         from pandas.core.reshape.pivot import pivot
#    6878
# -> 6879         return pivot(self, index=index, columns=columns, values=values)
#    6880
#    6881     _shared_docs[
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot(data, index, columns, values)
#     439
#     440         append = index is None
# --> 441         indexed = data.set_index(cols + columns, append=append)
#     442     else:
#     443         if index is None:
#
# ...

# %%
df_lon.plot(kind='area', 
             stacked=False,
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('London Crime June 2021')
plt.ylabel('LSOA name')
plt.xlabel('Crime type')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-9b07f511ddf9> in <module>
#       4              )
#       5
# ----> 6 plt.title('London Crime June 2021')
#       7 plt.ylabel('LSOA name')
#       8 plt.xlabel('Crime type')
#
# NameError: name 'plt' is not defined

# %%
df_area = df_lon.groupby(['LSOA name','Crime type'],as_index = False).count().pivot('LSOA name','Crime type')

# %% [markdown]
# # Area Plot

# %%
#Preprocessing
df_area = df_lon.groupby(['LSOA name','Crime type'],as_index = False).sum().pivot('LSOA name','Crime type')
